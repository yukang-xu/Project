# %% [markdown]
# <img src="https://newsroom.unl.edu/announce/files/file121687.png" width="100" height="100" />

# %% [markdown]
# ##    <center>Meet your NBA Assistant Manager: Recommender System and Next best Transaction

# %% [markdown]
# The similar trend below shows a positive relationship between standing and the number of trades.
#
# But sometimes, injuries and trades are inevitable (just to think about Contract termination, Age etc.). Here is where our recommender system comes into picture and how it helps in two ways. Once you type in a team’s name such as LA Lakers, it assists our manger to analyze current trading market and list the best fits to the team. They could be the perfect substitute players without losing chemistry of the team. Besides, if plugging in a name, this system could narrow down our trading targets similar as key players who will be leaving and we could expect they play the almost the same role in the team. All in all, team could take full advantage of data from two dimensions (i.e. team and players levels) by using the system.

# %%
### AVG number of Trades since 2017 ###
